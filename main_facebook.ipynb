# %% [markdown]
# # ORQUESTADOR *************************************************************

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from scraping.extractor_facebook import iniciar_sesion

try:
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    ok = iniciar_sesion(
        driver,
        user="jamoncayop@gmail.com",
        pwd="Adaptiv3"
    )

    if ok:
        print("¡Has iniciado sesión en Facebook! (Aquí nos detenemos por ahora)")

except Exception as e:
    print("❌ Error en la ejecución:", e)
finally:
    if driver:
        driver.quit()
# Out:
# 🌐 Abriendo página de login de Facebook…
# ✍️ Credenciales ingresadas.
# 👉 Click en 'Iniciar sesión'.
# ✅ Sesión iniciada. URL actual: https://www.facebook.com/
# ¡Has iniciado sesión en Facebook! (Aquí nos detenemos por ahora)
